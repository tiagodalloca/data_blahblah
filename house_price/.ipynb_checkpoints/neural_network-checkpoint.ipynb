# %%
# Importing the modules 
import numpy as np
import pandas as pd 
from sklearn.model_selection import train_test_split
from sklearn import metrics
import matplotlib.pyplot as plt
# %matplotlib inline

df = pd.read_csv('kc_house_data.csv')
df.drop(['id', 'grade'], inplace=True, axis=1)
df.head()
# Out:
#               date     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  20141013T000000  221900.0         3       1.00         1180      5650
# 1  20141209T000000  538000.0         3       2.25         2570      7242
# 2  20150225T000000  180000.0         2       1.00          770     10000
# 3  20141209T000000  604000.0         4       3.00         1960      5000
# 4  20150218T000000  510000.0         3       2.00         1680      8080
#
#    floors  waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# 0     1.0           0     0          3        1180              0      1955
# 1     2.0           0     0          3        2170            400      1951
# 2     1.0           0     0          3         770              0      1933
# 3     1.0           0     0          5        1050            910      1965
# 4     1.0           0     0          3        1680              0      1987
#
#    yr_renovated  zipcode      lat     long  sqft_living15  sqft_lot15
# 0             0    98178  47.5112 -122.257           1340        5650
# 1          1991    98125  47.7210 -122.319           1690        7639
# 2             0    98028  47.7379 -122.233           2720        8062
# 3             0    98136  47.5208 -122.393           1360        5000
# 4             0    98074  47.6168 -122.045           1800        7503

# %%
df.describe()
# Out:
#               price      bedrooms     bathrooms   sqft_living      sqft_lot  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  2.161300e+04
# mean   5.400881e+05      3.370842      2.114757   2079.899736  1.510697e+04
# std    3.671272e+05      0.930062      0.770163    918.440897  4.142051e+04
# min    7.500000e+04      0.000000      0.000000    290.000000  5.200000e+02
# 25%    3.219500e+05      3.000000      1.750000   1427.000000  5.040000e+03
# 50%    4.500000e+05      3.000000      2.250000   1910.000000  7.618000e+03
# 75%    6.450000e+05      4.000000      2.500000   2550.000000  1.068800e+04
# max    7.700000e+06     33.000000      8.000000  13540.000000  1.651359e+06
#
#              floors    waterfront          view     condition    sqft_above  \
# count  21613.000000  21613.000000  21613.000000  21613.000000  21613.000000
# mean       1.494309      0.007542      0.234303      3.409430   1788.390691
# std        0.539989      0.086517      0.766318      0.650743    828.090978
# min        1.000000      0.000000      0.000000      1.000000    290.000000
# 25%        1.000000      0.000000      0.000000      3.000000   1190.000000
# 50%        1.500000      0.000000      0.000000      3.000000   1560.000000
# 75%        2.000000      0.000000      0.000000      4.000000   2210.000000
# max        3.500000      1.000000      4.000000      5.000000   9410.000000
#
#        sqft_basement      yr_built  yr_renovated       zipcode           lat  \
# count   21613.000000  21613.000000  21613.000000  21613.000000  21613.000000
# mean      291.509045   1971.005136     84.402258  98077.939805     47.560053
# std       442.575043     29.373411    401.679240     53.505026      0.138564
# min         0.000000   1900.000000      0.000000  98001.000000     47.155900
# 25%         0.000000   1951.000000      0.000000  98033.000000     47.471000
# 50%         0.000000   1975.000000      0.000000  98065.000000     47.571800
# 75%       560.000000   1997.000000      0.000000  98118.000000     47.678000
# max      4820.000000   2015.000000   2015.000000  98199.000000     47.777600
#
#                long  sqft_living15     sqft_lot15
# count  21613.000000   21613.000000   21613.000000
# mean    -122.213896    1986.552492   12768.455652
# std        0.140828     685.391304   27304.179631
# min     -122.519000     399.000000     651.000000
# 25%     -122.328000    1490.000000    5100.000000
# 50%     -122.230000    1840.000000    7620.000000
# 75%     -122.125000    2360.000000   10083.000000
# max     -121.315000    6210.000000  871200.000000

# %%
df['date'] = df['date'].apply(lambda x: np.float(x.split('T')[0]))
df.head()
# Out:
#          date     price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0  20141013.0  221900.0         3       1.00         1180      5650     1.0
# 1  20141209.0  538000.0         3       2.25         2570      7242     2.0
# 2  20150225.0  180000.0         2       1.00          770     10000     1.0
# 3  20141209.0  604000.0         4       3.00         1960      5000     1.0
# 4  20150218.0  510000.0         3       2.00         1680      8080     1.0
#
#    waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# 0           0     0          3        1180              0      1955
# 1           0     0          3        2170            400      1951
# 2           0     0          3         770              0      1933
# 3           0     0          5        1050            910      1965
# 4           0     0          3        1680              0      1987
#
#    yr_renovated  zipcode      lat     long  sqft_living15  sqft_lot15
# 0             0    98178  47.5112 -122.257           1340        5650
# 1          1991    98125  47.7210 -122.319           1690        7639
# 2             0    98028  47.7379 -122.233           2720        8062
# 3             0    98136  47.5208 -122.393           1360        5000
# 4             0    98074  47.6168 -122.045           1800        7503

# %%
df.head()
# Out:
#          date     price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0  20141013.0  221900.0         3       1.00         1180      5650     1.0
# 1  20141209.0  538000.0         3       2.25         2570      7242     2.0
# 2  20150225.0  180000.0         2       1.00          770     10000     1.0
# 3  20141209.0  604000.0         4       3.00         1960      5000     1.0
# 4  20150218.0  510000.0         3       2.00         1680      8080     1.0
#
#    waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# 0           0     0          3        1180              0      1955
# 1           0     0          3        2170            400      1951
# 2           0     0          3         770              0      1933
# 3           0     0          5        1050            910      1965
# 4           0     0          3        1680              0      1987
#
#    yr_renovated  zipcode      lat     long  sqft_living15  sqft_lot15
# 0             0    98178  47.5112 -122.257           1340        5650
# 1          1991    98125  47.7210 -122.319           1690        7639
# 2             0    98028  47.7379 -122.233           2720        8062
# 3             0    98136  47.5208 -122.393           1360        5000
# 4             0    98074  47.6168 -122.045           1800        7503

# %%
prices = df['price']
df = (df - df.mean())/(df.max() - df.min())
#df['price'] = prices

train_validation_data,test_data = train_test_split(df,train_size = 0.8,random_state=3)

train_data,val_data = train_test_split(train_validation_data,train_size = 0.7,random_state=3)
# Out:
# /home/tiago/anaconda3/lib/python3.6/site-packages/sklearn/model_selection/_split.py:2026: FutureWarning: From version 0.21, test_size will always complement train_size unless both are specified.
#   FutureWarning)

# %%
df.head()
# Out:
#        date     price  bedrooms  bathrooms  sqft_living  sqft_lot    floors  \
# 0 -0.288246 -0.041730 -0.011238  -0.139345    -0.067917 -0.005729 -0.197724
# 1 -0.268695 -0.000274 -0.011238   0.016905     0.036989 -0.004764  0.202276
# 2  0.630657 -0.047225 -0.041541  -0.139345    -0.098860 -0.003094 -0.197724
# 3 -0.268695  0.008382  0.019065   0.110655    -0.009049 -0.006122 -0.197724
# 4  0.629958 -0.003946 -0.011238  -0.014345    -0.030181 -0.004257 -0.197724
#
#    waterfront      view  condition  sqft_above  sqft_basement  yr_built  \
# 0   -0.007542 -0.058576  -0.102357   -0.066710      -0.060479 -0.139175
# 1   -0.007542 -0.058576  -0.102357    0.041843       0.022508 -0.173958
# 2   -0.007542 -0.058576  -0.102357   -0.111666      -0.060479 -0.330479
# 3   -0.007542 -0.058576   0.397643   -0.080964       0.128318 -0.052219
# 4   -0.007542 -0.058576  -0.102357   -0.011885      -0.060479  0.139086
#
#    yr_renovated   zipcode       lat      long  sqft_living15  sqft_lot15
# 0     -0.041887  0.505355 -0.078579 -0.035800      -0.111264   -0.008177
# 1      0.946202  0.237678  0.258883 -0.087295      -0.051033   -0.005892
# 2     -0.041887 -0.252221  0.286066 -0.015867       0.126217   -0.005406
# 3     -0.041887  0.293233 -0.063137 -0.148757      -0.107822   -0.008924
# 4     -0.041887 -0.019898  0.091278  0.140279      -0.032103   -0.006048

# %%
xs = train_data.drop('price', axis=1).values
ys = train_data['price'].values

val_ys = val_data['price'].values
val_xs = val_data.drop('price', axis=1).values

# %%
def show_loss_chart(history):
    loss = history.history['_loss']
    val_loss = history.history['val_loss']
    epochs = range(1, len(loss) + 1)
    plt.plot(epochs, loss, 'bo', label='Training loss')
    plt.plot(epochs, val_loss, 'b', label='Validation loss')
    plt.title('Training and validation loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.show()
    
def show_accuracy_chart(history):
    acc = history.history['mean_absolute_error']
    val_acc = history.history['val_mean_absolute_error']
    epochs = range(1, len(acc) + 1)
    plt.plot(epochs, acc, 'bo', label='Training mean_absolute_error')
    plt.plot(epochs, val_acc, 'b', label='Validation mean_absolute_error')
    plt.title('Training and validation accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Mean Abs Error')
    plt.legend()
    plt.show()

# %%
from keras import models
from keras import layers
from keras.models import Model


inp = layers.Input((xs.shape[1],))
x = layers.Dense(16, activation='relu')(inp)
x = layers.Dense(8, activation='relu')(x)

out1 = layers.Dense(1, activation='linear', name='price')(x)

model = Model(inputs=inp, outputs=[out1])

from keras import optimizers

model.compile(optimizer='rmsprop', loss=['mse'], 
              metrics={ 'price': 'mae'})

# %%
history = model.fit(x=xs,
                    y=ys,
                    epochs=30,
                    validation_data=(val_xs,val_ys))

show_accuracy_chart(history)
# Out:
# Train on 12103 samples, validate on 5187 samples
# Epoch 1/30
# 12103/12103 [==============================] - 0s 37us/step - loss: 2.5228e-04 - mean_absolute_error: 0.0101 - val_loss: 3.3666e-04 - val_mean_absolute_error: 0.0108
# Epoch 2/30
# 12103/12103 [==============================] - 0s 34us/step - loss: 2.5234e-04 - mean_absolute_error: 0.0101 - val_loss: 3.7519e-04 - val_mean_absolute_error: 0.0127
# Epoch 3/30
# 12103/12103 [==============================] - 0s 38us/step - loss: 2.5036e-04 - mean_absolute_error: 0.0101 - val_loss: 3.9595e-04 - val_mean_absolute_error: 0.0134
# Epoch 4/30
# 12103/12103 [==============================] - 1s 47us/step - loss: 2.5191e-04 - mean_absolute_error: 0.0101 - val_loss: 3.5466e-04 - val_mean_absolute_error: 0.0117
# Epoch 5/30
# 12103/12103 [==============================] - 0s 39us/step - loss: 2.4641e-04 - mean_absolute_error: 0.0100 - val_loss: 3.3834e-04 - val_mean_absolute_error: 0.0107
# Epoch 6/30
# 12103/12103 [==============================] - 0s 36us/step - loss: 2.5077e-04 - mean_absolute_error: 0.0100 - val_loss: 3.3723e-04 - val_mean_absolute_error: 0.0110
# Epoch 7/30
# 12103/12103 [==============================] - 0s 38us/step - loss: 2.5082e-04 - mean_absolute_error: 0.0100 - val_loss: 3.8232e-04 - val_mean_absolute_error: 0.0120
# Epoch 8/30
# 12103/12103 [==============================] - 0s 36us/step - loss: 2.4816e-04 - mean_absolute_error: 0.0100 - val_loss: 3.3845e-04 - val_mean_absolute_error: 0.0110
# Epoch 9/30
# 12103/12103 [==============================] - 0s 37us/step - loss: 2.4874e-04 - mean_absolute_error: 0.0101 - val_loss: 3.6271e-04 - val_mean_absolute_error: 0.0123
# Epoch 10/30
# 12103/12103 [==============================] - 0s 36us/step - loss: 2.5146e-04 - mean_absolute_error: 0.0101 - val_loss: 3.3315e-04 - val_mean_absolute_error: 0.0106
# Epoch 11/30
# 12103/12103 [==============================] - 0s 40us/step - loss: 2.4708e-04 - mean_absolute_error: 0.0100 - val_loss: 3.7239e-04 - val_mean_absolute_error: 0.0119
# Epoch 12/30
# 12103/12103 [==============================] - 0s 38us/step - loss: 2.4905e-04 - mean_absolute_error: 0.0101 - val_loss: 3.6151e-04 - val_mean_absolute_error: 0.0122
# Epoch 13/30
# 12103/12103 [==============================] - 0s 37us/step - loss: 2.4809e-04 - mean_absolute_error: 0.0101 - val_loss: 3.8590e-04 - val_mean_absolute_error: 0.0129
# Epoch 14/30
# 12103/12103 [==============================] - 0s 37us/step - loss: 2.5088e-04 - mean_absolute_error: 0.0101 - val_loss: 3.8723e-04 - val_mean_absolute_error: 0.0128
# Epoch 15/30
# 12103/12103 [==============================] - 0s 40us/step - loss: 2.5044e-04 - mean_absolute_error: 0.0101 - val_loss: 3.8627e-04 - val_mean_absolute_error: 0.0115
# Epoch 16/30
# 12103/12103 [==============================] - 0s 40us/step - loss: 2.4512e-04 - mean_absolute_error: 0.0101 - val_loss: 3.3242e-04 - val_mean_absolute_error: 0.0106
# Epoch 17/30
# 12103/12103 [==============================] - 0s 35us/step - loss: 2.4944e-04 - mean_absolute_error: 0.0100 - val_loss: 3.3465e-04 - val_mean_absolute_error: 0.0106
# Epoch 18/30
# 12103/12103 [==============================] - 0s 38us/step - loss: 2.4254e-04 - mean_absolute_error: 0.0100 - val_loss: 4.2050e-04 - val_mean_absolute_error: 0.0144
# Epoch 19/30
# 12103/12103 [==============================] - 1s 43us/step - loss: 2.4920e-04 - mean_absolute_error: 0.0100 - val_loss: 3.3649e-04 - val_mean_absolute_error: 0.0107
# Epoch 20/30
# 12103/12103 [==============================] - 1s 50us/step - loss: 2.4991e-04 - mean_absolute_error: 0.0101 - val_loss: 3.3658e-04 - val_mean_absolute_error: 0.0108
# Epoch 21/30
# 12103/12103 [==============================] - 0s 36us/step - loss: 2.4475e-04 - mean_absolute_error: 0.0100 - val_loss: 3.2609e-04 - val_mean_absolute_error: 0.0106
# Epoch 22/30
# 12103/12103 [==============================] - 0s 38us/step - loss: 2.4915e-04 - mean_absolute_error: 0.0101 - val_loss: 3.5136e-04 - val_mean_absolute_error: 0.0115
# Epoch 23/30
# 12103/12103 [==============================] - 0s 37us/step - loss: 2.4700e-04 - mean_absolute_error: 0.0100 - val_loss: 3.5790e-04 - val_mean_absolute_error: 0.0116
# Epoch 24/30
# 12103/12103 [==============================] - 0s 37us/step - loss: 2.4788e-04 - mean_absolute_error: 0.0100 - val_loss: 3.4435e-04 - val_mean_absolute_error: 0.0109
# Epoch 25/30
# 12103/12103 [==============================] - 0s 37us/step - loss: 2.4653e-04 - mean_absolute_error: 0.0100 - val_loss: 3.7241e-04 - val_mean_absolute_error: 0.0119
# Epoch 26/30
# 12103/12103 [==============================] - 0s 36us/step - loss: 2.4919e-04 - mean_absolute_error: 0.0100 - val_loss: 4.5787e-04 - val_mean_absolute_error: 0.0153
# Epoch 27/30
# 12103/12103 [==============================] - 0s 38us/step - loss: 2.4732e-04 - mean_absolute_error: 0.0101 - val_loss: 3.2906e-04 - val_mean_absolute_error: 0.0108
# Epoch 28/30
# 12103/12103 [==============================] - 0s 37us/step - loss: 2.4906e-04 - mean_absolute_error: 0.0100 - val_loss: 3.4226e-04 - val_mean_absolute_error: 0.0109
# Epoch 29/30
# 12103/12103 [==============================] - 0s 37us/step - loss: 2.4483e-04 - mean_absolute_error: 0.0100 - val_loss: 3.9185e-04 - val_mean_absolute_error: 0.0125
# Epoch 30/30
# 12103/12103 [==============================] - 0s 37us/step - loss: 2.4951e-04 - mean_absolute_error: 0.0100 - val_loss: 3.3772e-04 - val_mean_absolute_error: 0.0108

# %%
test_ys = test_data['price'].values
test_xs = test_data.drop('price', axis=1).values

score, acc = model.evaluate(test_xs,
                            test_ys,
                            batch_size=32)

pv = prices.values

predicted_ys = np.array([x*(np.max(pv) - np.min(pv)) + np.mean(pv)
                         for x in model.predict(test_xs)])

test_pv = np.array([x*(np.max(pv) - np.min(pv)) + np.mean(pv)
                         for x in test_ys])

print('Test score:', score)
print('Test accuracy:', acc)
print('R²:', metrics.r2_score(test_pv, predicted_ys))
print('MSE', metrics.mean_absolute_error(test_pv, predicted_ys))
# Out:
# 4323/4323 [==============================] - 0s 19us/step
# Test score: 0.00030308614928814363
# Test accuracy: 0.01055745758881468
# R²: 0.8627177588032143
# MSE 80500.61284842702

# %%
pv.shape
# Out:
# (21613,)
